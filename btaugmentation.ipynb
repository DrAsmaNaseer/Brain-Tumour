# %%
import PIL
from PIL import Image

# load the image
image = Image.open('../input/brain-tumor-detection/yes/yes1.jpg')
# summarize some details about the image
print(image.format)#JPEG
print(image.mode)#RGB
print(image.size)#(338. 345)
# show the image
image.show()
# Out:
# JPEG
# RGB
# (338, 345)

# %%
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
data = image.imread('../input/brain-tumor-detection/yes/yes1.jpg')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
# Out:
# uint8
# (345, 338, 3)

# %%
# load image and convert to and from NumPy array
from PIL import Image
from numpy import asarray
# load the image
image = Image.open('../input/brain-tumor-detection/yes/yes1.jpg')

# convert image to numpy array
data = asarray(image)

# summarize shape
print(data.shape) #(rows, col, chnels)

# create Pillow image
image2 = Image.fromarray(data)

# summarize image details
print(image2.format)#None before conversion it was JPEG
print(image2.mode)#RGB
print(image2.size)#(cols, rows)
# Out:
# (345, 338, 3)
# None
# RGB
# (338, 345)

# %%
# load all images in a directory
from os import listdir
from matplotlib import image
from PIL import Image

# load all images in a directory
loaded_images = list()
for filename in listdir('../input/brain-tumor-detection/yes'):
    # load image
    img_dat = image.imread('../input/brain-tumor-detection/yes/' + filename)
    # store loaded image
    loaded_images.append(img_data)
    print('> loaded %s %s' % (filename, img_data.shape))
# Out:
# > loaded yes245.jpg (238, 249, 3)
# > loaded yes172.jpg (238, 249, 3)
# > loaded yes170.jpg (238, 249, 3)
# > loaded yes232.jpg (238, 249, 3)
# > loaded yes55.jpg (238, 249, 3)
# > loaded yes9.jpg (238, 249, 3)
# > loaded yes210.jpg (238, 249, 3)
# > loaded yes178.jpg (238, 249, 3)
# > loaded yes118.jpg (238, 249, 3)
# > loaded yes144.jpg (238, 249, 3)
# > loaded yes141.jpg (238, 249, 3)
# > loaded yes109.jpg (238, 249, 3)
# > loaded yes51.jpg (238, 249, 3)
# > loaded yes30.jpg (238, 249, 3)
# > loaded yes161.jpg (238, 249, 3)
# > loaded yes66.jpg (238, 249, 3)
# > loaded yes31.jpg (238, 249, 3)
# > loaded yes45.jpg (238, 249, 3)
# > loaded yes164.jpg (238, 249, 3)
# > loaded yes90.jpg (238, 249, 3)
# > loaded yes189.jpg (238, 249, 3)
# > loaded yes171.jpg (238, 249, 3)
# > loaded yes26.jpg (238, 249, 3)
# > loaded yes113.jpg (238, 249, 3)
# > loaded yes116.jpg (238, 249, 3)
# > loaded yes36.jpg (238, 249, 3)
# > loaded yes220.jpg (238, 249, 3)
# > loaded yes132.jpg (238, 249, 3)
# ...

# %%
# example of saving a grayscale version of a loaded image
from PIL import Image
# load the image
image = Image.open('../input/brain-tumor-detection/yes/yes1.jpg')
# convert the image to grayscale
gs_image = image.convert(mode='L')
# save in jpeg format
gs_image.save('opera_house_grayscale.jpg')
# load the image again and show it
image2 = Image.open('opera_house_grayscale.jpg')
# show the image
image2.show()

# %%
# create flipped versions of an image
from PIL import Image
from matplotlib import pyplot
# load image
image = Image.open('../input/brain-tumor-detection/yes/yes1.jpg')
# horizontal flip
hoz_flip = image.transpose(Image.FLIP_LEFT_RIGHT)
# vertical flip
ver_flip = image.transpose(Image.FLIP_TOP_BOTTOM)
# plot all three images using matplotlib
pyplot.subplot(311)
pyplot.imshow(image)
pyplot.subplot(312)
pyplot.imshow(hoz_flip)
pyplot.subplot(313)
pyplot.imshow(ver_flip)
pyplot.show()

# %%
# create rotated versions of an image
from PIL import Image
from matplotlib import pyplot
# load image
image = Image.open('../input/brain-tumor-detection/yes/yes1.jpg')
# plot original image
pyplot.subplot(311)
pyplot.imshow(image)
# rotate 45 degrees
pyplot.subplot(312)
pyplot.imshow(image.rotate(45))
# rotate 90 degrees
pyplot.subplot(313)
pyplot.imshow(image.rotate(90))
pyplot.show()

# %%
import cv2
import os
import numpy as np



images = []
folder="../input/brain-tumor-detection/yes"
for filename in os.listdir(folder):
    img = cv2.imread(os.path.join(folder,filename))
    if img is not None:
        images.append(img)
    
print('Loaded all images..')
# Out:
# Loaded all images..
